# %% [markdown]
# <a href="https://colab.research.google.com/github/sandrachu/Introduction-to-Computers/blob/main/0330.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
not(3>5)
# Out:
# True

# %%
not(5>3)
# Out:
# False

# %%
(5>3)and(9>6)
# Out:
# True

# %%
(5>3)and(9<6)
# Out:
# False

# %%
(5<3)and(9>6)
# Out:
# False

# %%
(5<3)and(9<6)
# Out:
# False

# %%
(5>3)or(9>6)
# Out:
# True

# %%
(5>3)or(9<6)
# Out:
# True

# %%
(5<3)or(9>6)
# Out:
# True

# %%
(5<3)or(9<6)
# Out:
# False

# %%
i=10

# %%
i+=5

# %%
i
# Out:
# 15

# %%
i-=5

# %%
i
# Out:
# 10

# %%
i=10
i*=5
i
# Out:
# 50

# %%
i=10
i/=5
i
# Out:
# 2.0

# %%
i=10
i%=5
i
# Out:
# 0

# %%
i=10
i//=5
i
# Out:
# 2

# %%
i=10
i**=3
i
# Out:
# 1000

# %%
print(1+2)
# Out:
# 3

# %%
print("1"+"2")
# Out:
# 12

# %%
print("你"+"好"+"!")
# Out:
# 你好!

# %%
deposit=int(input('請輸入本金存款金額:'))
years=1.02**6
deposit*=years
print('6年後存款為:'+str(deposit))
# Out:
# 請輸入本金存款金額:10000
# 6年後存款為:11261.62419264

# %%
pw=input('請輸入密碼')
if(pw=='1234'):
    print('歡迎光臨!')
# Out:
# 請輸入密碼1234
# 歡迎光臨!

# %%
rain=input("今天會下雨嗎?")
if(rain=="Y"or rain=="y"):
    print("出門記得帶傘!")
# Out:
# 今天會下雨嗎?y
# 出門記得帶傘!

# %%
pw=input('請輸入密碼')
if(pw=='1234'):
    print('歡迎光臨!')
else:
    print('密碼錯誤!')
# Out:
# 請輸入密碼1111
# 密碼錯誤!

# %%
rain=input("今天會下雨嗎?")
if(rain=="Y"or rain=="y"):
    print("出門記得帶傘!")
else:
    print('不用帶傘')
# Out:
# 今天會下雨嗎?no
# 不用帶傘

# %%
num=int(input('請輸入正整數:'))
if(num%2)==0:
    print(num,'為偶數!',sep='')
else:
    print(num,'為奇數!',sep='')
# Out:
# 請輸入正整數:51
# 51為奇數!
